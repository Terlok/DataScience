# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import zipfile
import wget
import random

# %%
def download_extract():
    try:
        remote_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00235/household_power_consumption.zip'
        wget.download(remote_url)
        File = zipfile.ZipFile('household_power_consumption.zip')
        File.extractall()
        File.close()
    except:
        print("Something went wrong")
    else:
        print("Nothing went wrong")

download_extract()

read_file = pd.read_csv (r'household_power_consumption.txt')
read_file.to_csv(r'household_power_consumption.csv', index=None)
# Out:
# Nothing went wrong

# %%
data = pd.read_csv('household_power_consumption.csv', sep=';', low_memory=False)
if data.isnull().values.any():
    missing_values = data.isnull().values.sum()
    print(f'Number of missing values: {missing_values}')
    data = data.dropna()
else:
    print('Our Dataset has no missing values.')
# Out:
# Number of missing values: 25979

# %%
convert_dict = {
    'Date': 'str', 
    'Time': 'str',
    'Global_active_power': 'float',
    'Global_reactive_power': 'float',
    'Voltage': 'float',
    'Global_intensity': 'float',
    'Sub_metering_1': 'float',
    'Sub_metering_2': 'float',
    'Sub_metering_3': 'float'
}
data = data.astype(convert_dict)
data.head()
# Out:
#          Date      Time  Global_active_power  Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00                4.216                  0.418   234.84
# 1  16/12/2006  17:25:00                5.360                  0.436   233.63
# 2  16/12/2006  17:26:00                5.374                  0.498   233.29
# 3  16/12/2006  17:27:00                5.388                  0.502   233.74
# 4  16/12/2006  17:28:00                3.666                  0.528   235.68
#
#    Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# 0              18.4             0.0             1.0            17.0
# 1              23.0             0.0             1.0            16.0
# 2              23.0             0.0             2.0            17.0
# 3              23.0             0.0             1.0            17.0
# 4              15.8             0.0             1.0            17.0

# %%
def first_task():
    args = data[(data.Global_active_power > 5.0)]
    print(f"A number of all households in which the total active power consumption exceeds 5 kW: {len(args)}")
    return args

def second_task():
    args = data[(data.Voltage > 235.0)]
    print(f"A number of all households where the voltage exceeds 235 V: {len(args)}")
    return args

def third_task():
    args = data[(data.Global_intensity >= 19) & (data.Global_intensity <= 20) & (data.Sub_metering_2 > data.Sub_metering_3)]
    print(f"A number of all households in which the current strength lies within the range of 19-20 A and... : {len(args)}")
    return args

def fourth_task():
    args = random.sample(range(len(data)), 500000)
    args.sort()
    df = data.iloc[args]
    result = pd.DataFrame.from_dict({
    'Sub_metering_1': [df['Sub_metering_1'].mean()], 
    'Sub_metering_2': [df['Sub_metering_2'].mean()], 
    'Sub_metering_3': [df['Sub_metering_3'].mean()]
    })
    return result

def fifth_task():
    args = data[(data.Time >= '18:00:00') & (data.Global_active_power > 6.0) & (data.Sub_metering_2 > data.Sub_metering_1) & (data.Sub_metering_2 > data.Sub_metering_3)]
    return args[:int(len(args)/2)], args[int(len(args)/2):]

# %%
first_task()
# Out:
# A number of all households in which the total active power consumption exceeds 5 kW: 17547
#                Date      Time  Global_active_power  Global_reactive_power  \
# 1        16/12/2006  17:25:00                5.360                  0.436
# 2        16/12/2006  17:26:00                5.374                  0.498
# 3        16/12/2006  17:27:00                5.388                  0.502
# 11       16/12/2006  17:35:00                5.412                  0.470
# 12       16/12/2006  17:36:00                5.224                  0.478
# ...             ...       ...                  ...                    ...
# 2069356  22/11/2010  18:40:00                5.408                  0.150
# 2069357  22/11/2010  18:41:00                5.528                  0.144
# 2071586  24/11/2010  07:50:00                5.172                  0.050
# 2071587  24/11/2010  07:51:00                5.750                  0.000
# ...

# %%
second_task()
# Out:
# A number of all households where the voltage exceeds 235 V: 1952491
#                Date      Time  Global_active_power  Global_reactive_power  \
# 4        16/12/2006  17:28:00                3.666                  0.528
# 5        16/12/2006  17:29:00                3.520                  0.522
# 6        16/12/2006  17:30:00                3.702                  0.520
# 7        16/12/2006  17:31:00                3.700                  0.520
# 14       16/12/2006  17:38:00                4.054                  0.422
# ...             ...       ...                  ...                    ...
# 2075254  26/11/2010  20:58:00                0.946                  0.000
# 2075255  26/11/2010  20:59:00                0.944                  0.000
# 2075256  26/11/2010  21:00:00                0.938                  0.000
# 2075257  26/11/2010  21:01:00                0.934                  0.000
# 2075258  26/11/2010  21:02:00                0.932                  0.000
#
# ...

# %%
third_task()
# Out:
# A number of all households in which the current strength lies within the range of 19-20 A and... : 2509
#                Date      Time  Global_active_power  Global_reactive_power  \
# 45       16/12/2006  18:09:00                4.464                  0.136
# 460      17/12/2006  01:04:00                4.582                  0.258
# 464      17/12/2006  01:08:00                4.618                  0.104
# 475      17/12/2006  01:19:00                4.636                  0.140
# 476      17/12/2006  01:20:00                4.634                  0.152
# ...             ...       ...                  ...                    ...
# 2071589  24/11/2010  07:53:00                4.666                  0.000
# 2071590  24/11/2010  07:54:00                4.694                  0.000
# 2071591  24/11/2010  07:55:00                4.602                  0.000
# 2071592  24/11/2010  07:56:00                4.536                  0.000
# ...

# %%
fourth_task()
# Out:
#    Sub_metering_1  Sub_metering_2  Sub_metering_3
# 0         1.13091        1.290328        6.464158

# %%
args_first_part, args_second_part = fifth_task()
args_first_part.iloc[[i for i in range(0, len(args_first_part), 3)]]
# Out:
#               Date      Time  Global_active_power  Global_reactive_power  \
# 41      16/12/2006  18:05:00                6.052                  0.192
# 44      16/12/2006  18:08:00                6.308                  0.116
# 17494   28/12/2006  20:58:00                6.386                  0.374
# 17498   28/12/2006  21:02:00                8.088                  0.262
# 17501   28/12/2006  21:05:00                7.230                  0.152
# ...            ...       ...                  ...                    ...
# 666904   23/3/2008  20:28:00                7.268                  0.192
# 666907   23/3/2008  20:31:00                6.958                  0.188
# 666910   23/3/2008  20:34:00                6.668                  0.180
# 695575   12/4/2008  18:19:00                6.568                  0.394
# 707257   20/4/2008  21:01:00                8.084                  0.288
#
#         Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# ...

# %%
args_second_part.iloc[[i for i in range(0, len(args_second_part), 4)]]
# Out:
#                Date      Time  Global_active_power  Global_reactive_power  \
# 707259    20/4/2008  21:03:00                7.798                  0.328
# 707263    20/4/2008  21:07:00                7.452                  0.346
# 707267    20/4/2008  21:11:00                6.436                  0.382
# 707271    20/4/2008  21:15:00                6.200                  0.216
# 747546    18/5/2008  20:30:00                6.760                  0.236
# ...             ...       ...                  ...                    ...
# 2066466  20/11/2010  18:30:00                6.620                  0.314
# 2066470  20/11/2010  18:34:00                6.266                  0.360
# 2066474  20/11/2010  18:38:00                6.302                  0.376
# 2066478  20/11/2010  18:42:00                6.238                  0.344
# 2066482  20/11/2010  18:46:00                6.438                  0.308
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# ...
